# %% [markdown]
# **What does this pipeline do?**
#    This pipeline is built to process 3' end sequencing data generated using the [3'READS+ method](https://www.ncbi.nlm.nih.gov/pubmed/27512124 "Pubmed"), which produces sequencing reads with ~13 Ts in the beginning of the reads. Reads containing >= 2 extra Ts originated from the poly(A) tail cannot be mapped to the genome and therefore are called PASS (PolyA Site Supporting) reads. The pipeline will search fastq files on the intron server, merge fastq files, do fastq QC, trim 3' adapter, trim 5' Ts, map reads to the genome, identify PASS reads and unique PASS reads, cluster PASS reads for defining poly(A) sites, and create genome browser tracks. Along the way it will generate a fastq QC report, a read statistics report, and a plot showing distributions of 5' T-stretch length.
#
#
# **What's cool about this pipeline?**
#  * I used both python and R seamlessly in one notebook. It is a great pleasure to mix python and R!
#  * I used parallel computing in in both python and R for all the heavy-lifting steps. It only took ~50 min to process 29 G fastq data for 8 samples on a laptop workstation (Lenovo P50 with 4 cores and 48G RAM).
#  * I developed my own algorithms to identify PASS reads and cluster them. The clustering algorithm uses a divide and conquer technique to cluster neighbouring cleavage sites due to microheterogeneity.

# %% [markdown]
# To install new package for the environment used by this notebook, type the following in a terminal:
# python3.6 -m pip install seaborn --user
#
# This environment was not managed by conda, thus the following command will not show the current environment:
# conda env list

# %%
# %load_ext rpy2.ipython 
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
from pathlib import Path
import re
import sys
import multiprocessing as mp
import numpy as np
import pandas as pd
import seaborn as sns
import rpy2.robjects.numpy2ri as n2r
import textwrap
import warnings
warnings.filterwarnings('ignore')

sys.path.append('modules')
from PASS import *
from time import sleep
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Set parameters specific to this project and experiment
# These parameters can be different for different runs. The sample discription file is in csv format with at least the following columns: "prefix" (unique beginning strings in the fastq files), "sample" (user defined sample name). This information can be used to make sample names more meaningful. "color_group" is optional, but can be used to groups different UCSC tracks by color. If not specified, a unique color will be used for each sample.

# %%
PROJECT = 'example' # project name
EXPERIMENT = '181210' # experiment name
GENOME = 'hg19' # genome name, either mm9 or hg19
SEQUENCER = 'nextseq' # Either "hiseq" or "nextseq"
SAMPLE_DESCRIPTION_FILE = 'sample_description.csv' # sample discription file.

#DATA_SOURCE = 'internal_server' # Where the raw data are stored. Can be "internal_server", "basespace", or "local".
#DATA_SOURCE = 'basespace'
DATA_SOURCE = 'local'
if DATA_SOURCE == 'internal_server':
    USER = 'zhengdh'
    SERVER = 'intron.njms.rutgers.edu'
elif DATA_SOURCE == 'basespace':
    BASESPACE_PROJECT = ''
    BASESPACE_TOKEN = ''
elif DATA_SOURCE == 'local':
    # LOCAL_DATA_SOURCE = 'path/on/local/computer' ### Don't use "~"
    LOCAL_DATA_SOURCE = '/home/dinghai/dev/3-prime-READS-plus/projects/example/data/181210/rawfastq'
    assert Path(LOCAL_DATA_SOURCE).exists()
    
FASTQ_QC_PLOT_NUM_COLUMNS = 4  # number of columns for fastq QC plots
SAVE_SPACE = False # to save space, delete intermediate files asap.    

GENOME_INDEX_DIR = '/home/dinghai/projects/fud/star_index' # Directory containing index files for different genomes
GENOME_FASTA_DIR = '/home/dinghai/projects/fud/ucsc/genomes' # Directory containing fasta files for different genomes


MAX_WORKERS = 8  # Maximum number of processes for parallel computing
CUTADAPT_MINLEN = 25  # minimum read lenth after removing 5' adapter
MAX_PA_DISTANCE = 24 # maximum distance between clustered reads

# %% [markdown]
# ## Set general parameters
# No need to change anything below for different runs.

# %%
# Genome index for STAR
genome_index = Path(GENOME_INDEX_DIR)/GENOME
# Genome sequence in fasta format for identifying PASS reads
genome_dir = Path(GENOME_FASTA_DIR)/GENOME
assert genome_index.exists(), f"Please make sure the following genome index folder exists: {str(genome_index)}"
assert genome_dir.exists(), f"Please make sure the following genome fasta file folder exists: {str(genome_dir)}"

# %%
# Project directory
project_dir = Path('projects')/PROJECT
# Script directory for saving project and experiment-specific scripts
script_dir = project_dir/'scripts'/EXPERIMENT
# Data directories
data_dir = project_dir/'data'/EXPERIMENT
rawfastq_dir = data_dir/'rawfastq'
fastq_dir = data_dir/'fastq'
sam_dir = data_dir/'sam'
# Result directory
result_dir = project_dir/'result'/EXPERIMENT
result_dir_str = str(result_dir.absolute())
# Create directories
project_dir.mkdir(parents=True, exist_ok=True)
script_dir.mkdir(parents=True, exist_ok=True)
data_dir.mkdir(parents=True, exist_ok=True)
rawfastq_dir.mkdir(parents=True, exist_ok=True)
fastq_dir.mkdir(parents=True, exist_ok=True)
sam_dir.mkdir(parents=True, exist_ok=True)
result_dir.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Read sample annotation and choose colors for UCSC tracks

# %%
sample_description = pd.read_csv(data_dir/SAMPLE_DESCRIPTION_FILE, dtype = 'str')

if not set(['warehouse_folder_unique_string', 'fastq_file_unique_string', 'sample']
          ) <= set(sample_description.columns):
    msg = '''
    The sample discription file should at least have the following columns: 
    "warehouse_folder_unique_string": unique string in the data warehouse folder name containing the fastq files, 
    "fastq_folder_unique_string": unique string in the fastq files corresponding to different samples,
    "sample": user defined sample name.
    '''
    msg = textwrap.dedent(msg).strip()
    print(msg)
    

# Remove potential whitespace 
sample_description.apply(lambda x: x.str.strip(), axis=1)
    
display(sample_description)    

print('The following colors will be used for UCSC genome browser tracks:')
if 'genome_browser_track_color' in sample_description.columns:
    color_max = sample_description.genome_browser_track_color.astype(int).max(axis=0)
else:
    color_max = sample_description.shape[0]
    
sns.palplot(sns.color_palette("colorblind", color_max))
# Out:
#   warehouse_folder_unique_string fastq_file_unique_string    sample  \
# 0                         181210                 siCtrl_1  siCtrl_1
# 1                         181210                  siYfg_1   siYfg_1
# 2                         181210                 siCtrl_2  siCtrl_2
# 3                         181210                  siYfg_2   siYfg_2
#
#   genome_browser_track_color
# 0                          1
# 1                          2
# 2                          1
# 3                          2
# The following colors will be used for UCSC genome browser tracks:

# %% [markdown]
# ## Find, download, merge, and rename fastq files
# Fastq files with the same file_string will be merged and renamed using the corresponding "sample" name defined in sample_description.csv.

# %%
# To rename multiple files, use command: mmv \*_small.fastq \#1.fastq

# %%
def merge_and_rename(selected_fastq_files, df):
    '''Unzip (if necessary), merge, and rename a list of selected fastq files. 
    selected_fastq_files: a list of selected fastq files. Must all be in either .fastq or .fastq.gz format.
    df: a sub-dataframe of sample_description used for renaming files
    '''    
    if len(selected_fastq_files) > 0:
        joint_file_names = ' '.join(selected_fastq_files)
        
        if selected_fastq_files[0].endswith('.gz'):
            print('Merging, unzipping, and renaming fastq files ....')
            cmd = f'cat {joint_file_names} | gunzip > {str(rawfastq_dir)}/{df[df.fastq_file_unique_string == file_string]["sample"].values[0]}.fastq'
        else:
            print('Merging and renaming fastq files ....')
            cmd = f'cat {joint_file_names} > {str(rawfastq_dir)}/{df[df.fastq_file_unique_string == file_string]["sample"].values[0]}.fastq'
        print(cmd)
        os.system(cmd)
        # Remove downloaded raw fastq files immediately to save space 
        cmd = 'rm ' + joint_file_names
        os.system(cmd)

# %%
for folder_string in sample_description.warehouse_folder_unique_string.unique():
    df = sample_description[sample_description.warehouse_folder_unique_string == folder_string]
    rawfastq_subdir = rawfastq_dir/folder_string
    rawfastq_subdir.mkdir(parents=True, exist_ok=True)
    
    if DATA_SOURCE == 'internal_server':
        # Find folder in the warehouse that may contain the fastq files
        cmd = f'ssh {USER}@{SERVER} find ../database* -type d -name *{folder_string}*'
        print(f'Looking for folders with {folder_string} in their names on the server {SERVER}')
        print(f'Using command {cmd}')
        fastq_folders = check_output(cmd, shell=True).decode().split('\n')
        print('Fastq folders found:')
        print('\n'.join(fastq_folders))

        # Find fastq files in the folders
        for file_string in df.fastq_file_unique_string:
            # Some of the folders may not contain fastq data
            for fastq_folder in fastq_folders:
                if SEQUENCER == "hiseq":
                    cmd = f'ssh {USER}@{SERVER} find {fastq_folder} -type f -name *{file_string}*R1*'
                elif SEQUENCER == "nextseq":
                    cmd = f'ssh {USER}@{SERVER} find {fastq_folder} -type f -name *{file_string}*'
                print(f'Serching files using the command {cmd}')
                fastq_files = check_output(cmd, shell=True).decode().replace('\n', " ")
                # Escape special characters
                fastq_files = fastq_files.replace("&", "\&").replace(":", "\:")
                print('Fastq files found:')
                print(fastq_files, '\n')
                if not fastq_files == '': # Skip the current fastq_folder if fastq_files have already been found
                    break
            # Download fastq files from internal server
            print('Downloading fastq files ....')
            cmd = f'scp {USER}@{SERVER}:"{fastq_files}" {rawfastq_subdir}'
            os.system(cmd)

            # Find fastq file names begining with file_string
            fastq_gz_with_file_string = [str(filename) for filename in rawfastq_subdir.iterdir() 
                                         if re.search(file_string + '.+fastq.gz$', str(filename))]
            fastq_with_file_string = [str(filename) for filename in rawfastq_subdir.iterdir() 
                                         if re.search(file_string + '.+fastq$', str(filename))]
            
            merge_and_rename(fastq_gz_with_file_string, df)
            merge_and_rename(fastq_with_file_string, df)
        
    elif DATA_SOURCE == 'local':
        cmd = f'find {LOCAL_DATA_SOURCE} -type d -name *{folder_string}*'
        # On the local computer, there is usually just one folder for each data set.
        fastq_folder = check_output(cmd, shell=True).decode().strip() 
        print('Fastq folders found:', fastq_folder)

        # Find fastq files in the folders
        for file_string in df.fastq_file_unique_string:
            if SEQUENCER == "hiseq":
                # find fastq file names begining with file_string
                fastq_gz_with_file_string = [str(filename) for filename in Path(fastq_folder).iterdir() 
                                             if re.search(file_string + '.*R1.+fastq.gz$', str(filename))]
                fastq_with_file_string = [str(filename) for filename in Path(fastq_folder).iterdir() 
                                          if re.search(file_string + '.*R1.+fastq$', str(filename))]
            elif SEQUENCER == "nextseq":
                fastq_gz_with_file_string = [str(filename) for filename in Path(fastq_folder).iterdir() 
                                             if re.search(file_string + '.+fastq.gz$', str(filename))]
                fastq_with_file_string = [str(filename) for filename in Path(fastq_folder).iterdir() 
                                          if re.search(file_string + '.+fastq$', str(filename))]
            
            merge_and_rename(fastq_gz_with_file_string, df)
            merge_and_rename(fastq_with_file_string, df)
    
    elif DATA_SOURCE == 'basespace':
        pass
# Out:
# Fastq folders found: /home/dinghai/dev/3-prime-READS-plus/projects/example/data/181210/rawfastq/181210
# Merging and renaming fastq files ....
# cat /home/dinghai/dev/3-prime-READS-plus/projects/example/data/181210/rawfastq/181210/siCtrl_1.fastq > projects/example/data/181210/rawfastq/siCtrl_1.fastq
# Merging and renaming fastq files ....
# cat /home/dinghai/dev/3-prime-READS-plus/projects/example/data/181210/rawfastq/181210/siYfg_1.fastq > projects/example/data/181210/rawfastq/siYfg_1.fastq
# Merging and renaming fastq files ....
# cat /home/dinghai/dev/3-prime-READS-plus/projects/example/data/181210/rawfastq/181210/siCtrl_2.fastq > projects/example/data/181210/rawfastq/siCtrl_2.fastq
# Merging and renaming fastq files ....
# cat /home/dinghai/dev/3-prime-READS-plus/projects/example/data/181210/rawfastq/181210/siYfg_2.fastq > projects/example/data/181210/rawfastq/siYfg_2.fastq

# %%
fastq_files = sorted([str(filename.absolute()) for filename in rawfastq_dir.glob('*.fastq')])

if len(fastq_files) == 0:
    print(f"Pleae put fastq files in the {str(rawfastq_dir)} folder first.")    
    
WORKERS = min(MAX_WORKERS, len(fastq_files))
print(f'{WORKERS} workers will be used for all parallel computing.')
# Out:
# 4 workers will be used for all parallel computing.

# %%
# Count raw reads   
with mp.Pool(processes=WORKERS) as pool:
    raw_fastq_counts = pool.map(count_fastq, fastq_files)
    
raw_fastq_counts = pd.DataFrame(raw_fastq_counts, columns = ["File_Name", "Raw"])
raw_fastq_counts["File_Name"] = raw_fastq_counts["File_Name"].str.replace('.fastq', '') 
raw_fastq_counts = raw_fastq_counts.set_index("File_Name")

# %%
raw_fastq_counts
# Out:
#                 Raw
# File_Name
# siCtrl_1_small  250
# siCtrl_2_small  250
# siYfg_1_small   250
# siYfg_2_small   250

# %% [markdown]
# ## FASTQ QC using R
# 1. python list -> R list (not vector)
# 2. Multiple inputs after -i can be separated using ",", without space.

# %%
# %%R -i fastq_files,FASTQ_QC_PLOT_NUM_COLUMNS,result_dir_str,WORKERS -w 1000 -h 1500
#
# ## load helper functions
# source("modules/FastqQC.R")
# library(foreach)
# library(doParallel)
#
# ## Step 1: Creat list of plots using parellel computing
# registerDoParallel(WORKERS)
# fqlist = foreach(f=1:length(fastq_files),
#                  .packages=c("ShortRead", "Biostrings")) %dopar%{
#     seeFastq(fastq=fastq_files[[f]])
#     }
# names(fqlist) = sapply(fastq_files, function(x) sub(".+\\/(.+).fastq", "\\1", x))
#
# ## Step 2: Output pdf and browser image
# n = min(FASTQ_QC_PLOT_NUM_COLUMNS, length(fastq_files))
# mycol = seq(along=fqlist)
# myrow = c(1, 3, 2, 4)
# if(length(mycol) %% n){
#   groups = 0:floor(length(mycol)/n)
# }else{
#   groups = 0:(length(mycol)/n - 1)
# }
# # Make pdf plots
# pdf(file.path(result_dir_str, "fastqReport.pdf"), height=20, width=4*n)
# for(group in groups){
#   if(group < max(groups)){
#     subcol = mycol[n*group + 1:n]
#   }else{
#     subcol = mycol[(n*group + 1):length(mycol)]
#   }
#   seeFastqPlot(fqlist[subcol], arrange=myrow, n = n)
# }
# dev.off()
# # Print to screen
# for(group in groups){
#   if(group < max(groups)){
#     subcol = mycol[n*group + 1:n]
#   }else{
#     subcol = mycol[(n*group + 1):length(mycol)]
#   }
#   seeFastqPlot(fqlist[subcol], arrange=myrow, n = n)
# }

# %% [markdown]
# **Automatically figure out the number of random nucleotides in the 3' adapter (5' end of the reads when the libraries are sequenced in reverse direction)** Usually the base after the random nucleotides has the highest frequency of Ts.

# %%
# %%R -o random_NT_lens
# cycle_with_max_T_frequency = function(fq){
#     base_frequency = fq$bstats
#     T_frequency = subset(base_frequency, Base == "T")
#     # The number of random nucleotides in the 3'adapter is also where the frequency of T increased most
#     which.max(diff(T_frequency$Frequency))
# }
# # For libraries prepared using different versions of 3' adapters (usually in different batches),
# # the numbers of random nucleotides could be different
# random_NT_lens = sapply(fqlist, cycle_with_max_T_frequency)
# cat("Number of random nucleotides in 3' adapter:", random_NT_lens)
# Out:
# Number of random nucleotides in 3' adapter: 6 6 6 6

# %% [markdown]
# ## Clip adapters

# %%
if SEQUENCER == 'hiseq':
    # Clip the read's 3' end adapter (originated from 5' RNA ligation adapter) and only keep 80 (150-70) nt
    cmds = [(f'cutadapt -u -70 -a NNNNTGGAATTCTCGGGTGCCAAGG -n 1 -O 10 -m {CUTADAPT_MINLEN} -f fastq '
             f'-q 10 {fastq_file} -o {fastq_file.replace(".fastq", ".cutadapt.fastq").replace("rawfastq", "fastq")} '
             f'&& rm {fastq_file}') for fastq_file in fastq_files]
    
elif SEQUENCER == 'nextseq':
    # Clip the read's 3' end adapter (originated from 5' RNA ligation adapter)
    cmds = [(f'cutadapt -a NNNNTGGAATTCTCGGGTGCCAAGG -n 1 -O 10 -m {CUTADAPT_MINLEN} -f fastq -q 10 {fastq_file} '
             f'-o {fastq_file.replace(".fastq", ".cutadapt.fastq").replace("rawfastq", "fastq")} '
             f'&& rm {fastq_file}') for fastq_file in fastq_files]


with mp.Pool(processes = WORKERS) as pool: 
    pool.map(os.system, cmds)

# %%
# # Count reads clipped by cutadapt
# cutadapt_fastq_files = sorted([str(filename.absolute()) for filename in fastq_dir.glob('*cutadapt.fastq')])

# with mp.Pool(processes = WORKERS) as pool: 
#     cutadapt_fastq_counts = pool.map(count_fastq, cutadapt_fastq_files)
    
# cutadapt_fastq_counts = pd.DataFrame(cutadapt_fastq_counts, columns = ["File_Name", "Cutadapt"])
# cutadapt_fastq_counts["File_Name"] = cutadapt_fastq_counts["File_Name"].str.replace('.cutadapt.fastq', '')

# %% [markdown]
# ## Trim 5' Ts

# %%
cutadapt_output = sorted([str(filename.absolute()) for filename in fastq_dir.glob('*cutadapt.fastq')])
with mp.Pool(processes = WORKERS) as pool:
    trimmed_fastq_counts = pool.starmap(trim_write_count_fastq, 
                            list(zip(cutadapt_output, list(random_NT_lens), [4]*len(random_NT_lens))))
    
if SAVE_SPACE:
    cmd = 'rm ' + ' '.join(cutadapt_fastq_files)
    os.system(cmd)    

trimmed_fastq_counts = pd.DataFrame(trimmed_fastq_counts, columns = ["File_Name", "Cut", "Trimmed"])
trimmed_fastq_counts["File_Name"] = trimmed_fastq_counts["File_Name"].str.replace('.cutadapt.fastq', '')  
trimmed_fastq_counts = trimmed_fastq_counts.set_index("File_Name")

# %%
trimmed_fastq_counts
# Out:
#                 Cut  Trimmed
# File_Name
# siCtrl_1        250      142
# siCtrl_1_small  250      142
# siCtrl_2        247      162
# siCtrl_2_small  247      162

# %% [markdown]
# ## Map the reads to the genome using STAR

# %% [markdown]
# AlignEndsType is set to EndToEnd.
# According to the STAR manual, add the following lines to /etc/sysctl.conf:
# 1. kernel.shmmax = 31000000000
# 2. kernel.shmall = 7568360
#
# Then run 'sudo /sbin/sysctl -p' to allow large shared memory blocks.

# %%
trimmed_fastq_files = sorted([str(filename.absolute()) for filename in fastq_dir.glob('*trimmed.fastq')])
# Commands for mapping reads
cmds = [(f'STAR --runThreadN {WORKERS} --genomeDir {genome_index} --genomeLoad LoadAndKeep '
         f'--readFilesIn {fastq_file} --alignEndsType EndToEnd --outFilterType BySJout '
         f'--outFilterMultimapNmax 10 --alignSJoverhangMin 8 --alignSJDBoverhangMin 1 '
         f'--alignIntronMin 20 --alignIntronMax 1000000 --outFileNamePrefix '
         f'{fastq_file.replace("/fastq/", "/sam/").replace("cutadapt.trimmed.fastq", "")}') 
         for fastq_file in trimmed_fastq_files]

# Commands for removing fastq files
cmds_rm = ['rm ' + fastq_file for fastq_file in trimmed_fastq_files]

# %%
# Map reads and then delete fastq files immediately
for i in range(len(cmds)):
    os.system(cmds[i])    
    if SAVE_SPACE:
        os.system(cmds_rm[i])
    
# Remove genome from memory. Note "--genomeDir" is still needed!
cmd = f'STAR --genomeDir {genome_index} --genomeLoad Remove'
os.system(cmd)
# Out:
# 0

# %% [markdown]
# ## Identfy PASS reads

# %% [markdown]
# 1. Unlike pool.map(), pool.starmap() allows passing multiple arguments to functions.
# 2. If I pass genome to each process, I will get an error.
# 3. If the pick_PASS is not defined in the notebook but loaded from PASS.py, genome will not be available for all processes.

# %%
def pick_PASS(sam_file, min_mapq = 10, direction = 'reverse', spike_in = None):
    '''Split sam_file into PASS, noPASS, and spike-in sam files.

    Loop through records in the sam file, if the record is PASS, write to
    pass_file. Mapped non-PASS reads are saved in nopass_file. Reads mapped to 
    rRNA genes are skipped. Sequencing direction can only be reverse or forward. 

    Attach matched tail length (ML), unmatched tail length (UL), and last mapped
    position (LM) to the end of readname. The head (such as 'TS11AAC') and the 
    tail (such as 'ML:i:4\tUL:i:9\tLM:i:1234') of the read name is the unique 
    identifier of the read.
    
    Arguments:
    sam_file: string. Name of input sam file.
    min_mapq: int. Minimum MAPQ score
    direction: string. Either 'reverse' (default) or 'forward'
    spike_in: a 4-charactor string for identifying spike-in RNA. For example,
    spike_in = 'ychr' for spike-in yeast RNA if yeast chromosomes are named as 'ychr1', 
    'ychrM', etc. 
    
    Outputs:
    Separate sam files containing either PASS reads, nonPASS reads, or spike-ins.
    '''
    pass_file = open(sam_file.replace('.sam', '.pass'), 'w')
    nopass_file = open(sam_file.replace('.sam', '.nopass'), 'w')
    if not spike_in: spike_in_file = open(sam_file.replace('.sam', '.spike_in'), 'w')
    
    lap = 0

    with open(sam_file, 'r') as in_file:
        for line in in_file:
            # Skip header
            if line[0] == '@':
                pass_file.write(line)
                nopass_file.write(line)
                if not spike_in: spike_in_file.write(line)
                continue
            # Process each line
            (readname, flag, chromosome, position, mapq, cigar) = line.split()[:6]
            position = int(position)
            mapq = int(mapq)

            # Discard reads with low mapping scores
            if mapq < min_mapq:
                continue
            # Record reads mapped to spiked-in yeast genome 
            if not spike_in and chromosome[:4] == spike_in:  
                spike_in_file.write(line)
                continue
            # Ignore reads mapped to other chromosomes, such as 'BK000964'
            if not chromosome[:3] == 'chr':
                continue

            # Extract the T-stretch length encoded in the readname
            match = re.match('TS(\d+)', line)
            if match:
                t_stretch_len = int(match.groups()[0])
            # Skip records with short T-stretches
            if not match or t_stretch_len < 2:
                nopass_file.write(line)
                continue

            # Get genomic sequence downstream of the LAP (last mapped position).
            # (The length of returned sequence is t_stretch_len.)
            if (direction.lower() == 'reverse' and flag == '16') or \
                    (direction.lower() == 'forward' and flag == '0'):
                strand = '+'
                # Process cigar to determine the LAP.
                # Insertion (I) will not affect the covered distance.
                nums = re.split('[MDN]', re.sub('\d+I', '', cigar))[:-1]
                covered = sum(int(x) for x in nums)
                # get_seq() returns reverse complemented sequence if strand == '-'
                downstream_seq = get_seq(chromosome, strand,
                                         start = position + covered,
                                         end = position + covered + t_stretch_len - 1,
                                         genome = genome)
                lap = position + covered - 1
            elif (direction.lower() == 'reverse' and flag == '0') or \
                    (direction.lower() == 'forward' and flag == '16'):
                strand = '-'
                downstream_seq = get_seq(chromosome, strand,
                                         start = position - t_stretch_len, 
                                         end = position - 1,
                                         genome = genome)
                lap = position
            else:
                nopass_file.write(line)
                continue

            # If the 5' T-stretch was trimmed twice (like 'TTTTTTTGTTTT'),
            # check whether GTTTT (reverse-compliment: AAAAC) comes from the genome
            elements = readname.split('::')
            if len(elements) == 2:
                elements[1] = elements[1].split(':')[0]   
                match = re.match(reverse_complement(elements[1]), downstream_seq)
                if match:
                    downstream_seq = downstream_seq[len(elements[1]):]
                    t_stretch_len -= len(elements[1])
                    if strand == '+':
                        lap += len(elements[1])
                    if strand == '-':
                        lap -= len(elements[1])
                    # If the t_stretch_len is reduced enough, no need to analyze downstream sequence
                    if t_stretch_len == 0:
                        nopass_file.write(line.strip() + '\tML:i:%d\tUL:i:%d\tLM:i:%d\n'
                                              % (0, 0, lap))
                        continue

            # Analyze downstream sequence
            if not downstream_seq[:-1] == 'A' * (t_stretch_len - 1):
                match = re.match('A+', downstream_seq)
                matched_len = len(match.group()) if match else 0
                # ML: Matched Length 
                # UL: Unmatched Length
                # LM: Last Mapped position(UL) 
                pass_file.write(line.strip() + '\tML:i:%d\tUL:i:%d\tLM:i:%d\n'
                                    % (matched_len, t_stretch_len - matched_len, lap))
            else:
                match = re.match('A*', downstream_seq)
                matched_len = len(match.group())  # value: 1 ~ t_stretch_len
                nopass_file.write(line.strip() + '\tML:i:%d\tUL:i:%d\tLM:i:%d\n'
                                      % (matched_len, t_stretch_len - matched_len, lap))

    pass_file.close()
    nopass_file.close()
    if not spike_in: spike_in_file.close()
    
    os.system('rm ' + sam_file)

# %%
# List of sam files as input
sam_files = sorted(str(sam_file) for sam_file in sam_dir.glob('*Aligned.out.sam'))

# Genome loaded into memory is available for all processes
genome = load_fasta_genome(genome_dir)

# Try parallel computing, which requires more disk space
try:
    with mp.Pool(processes = WORKERS) as pool:
        pool.starmap(pick_PASS, [(sam_file, 10, 'reverse') for sam_file in sam_files])
except OSError:
    os.system('rm ' + sam_dir + '/*pass')
    print("No space left on device. Trying again with parallel computing turned off.")
    for sam_file in sam_files:
        print("Processing ", sam_file)
        pick_PASS(sam_file = sam_file)

# Release memory    
del genome

# %% [markdown]
# ## Count unique PASS reads

# %%
pass_files = sorted(str(pass_file) for pass_file in sam_dir.glob('*Aligned.out.pass'))
 
with mp.Pool(processes=WORKERS) as pool:
    pool.starmap(select_unique_reads, list(zip(pass_files, list(random_NT_lens))))

# %% [markdown]
# ## Cluster PASS reads

# %%
# this steps cannot be parallized. I have tried to run the following steps in parallel,
# but some how the second job did not finish and did not complain.

# cluster all PASS reads
cluster_reads(file_pattern='.Aligned.out.pass',
                             outfile='cluster.all.reads.csv',
                             direction='reverse',
                             max_distance=MAX_PA_DISTANCE)
# cluster unique PASS reads
cluster_reads(file_pattern='.Aligned.out.unique.pass',
                             outfile='cluster.unique.reads.csv',
                             direction='reverse',
                             max_distance=MAX_PA_DISTANCE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-55d0ba40aae1> in <module>()
#       6                              outfile='cluster.all.reads.csv',
#       7                              direction='reverse',
# ----> 8                              max_distance=MAX_PA_DISTANCE)
#       9 # cluster unique PASS reads
#      10 cluster_reads(file_pattern='.Aligned.out.unique.pass',
#
# ~/dev/3-prime-READS-plus/modules/PASS.py in cluster_reads(file_pattern, outfile, direction, max_distance)
#     565
#     566     import os
# --> 567     sam_files = [file_name for file_name in os.listdir(sam_dir)
#     568                  if file_name.endswith(file_pattern)]
#     569     sam_file_num = len(sam_files)
#
# NameError: name 'sam_dir' is not defined

# %% [markdown]
# ## Read number statistics

# %%
### file names for PASS files
pass_files = sorted(glob.glob(os.path.join(sam_dir, 
                                           '*cutadapt.trimmed.Aligned.out.pass')))
nonpass_files = sorted(glob.glob(os.path.join(sam_dir, 
                                              '*cutadapt.trimmed.Aligned.out.nopass')))
upass_files = sorted(glob.glob(os.path.join(sam_dir, 
                                            '*cutadapt.trimmed.Aligned.out.unique.pass')))
spike_in_files = sorted(glob.glob(os.path.join(sam_dir, 
                                          '*cutadapt.trimmed.Aligned.out.spike_in')))

### parallel computing
with mp.Pool(processes=WORKERS) as pool: 
    pass_counts = pool.map(count_pass, pass_files)
pass_counts = pd.Series([x[1] for x in pass_counts], 
                        [x[0] for x in pass_counts], 
                        name = "PASS")

with mp.Pool(processes=WORKERS) as pool: 
    nonpass_counts = pool.map(count_pass, nonpass_files)
nonpass_counts = pd.Series([x[1] for x in nonpass_counts], 
                           [x[0] for x in nonpass_counts], 
                           name = "nonPASS")

with mp.Pool(processes=WORKERS) as pool: 
    upass_counts = pool.map(count_pass, upass_files)
upass_counts = pd.Series([x[1] for x in upass_counts], 
                         [x[0] for x in upass_counts], 
                         name = "uPASS")

with mp.Pool(processes=WORKERS) as pool: 
    spike_in_counts = pool.map(count_pass, spike_in_files)
spike_in_counts = pd.Series([x[1] for x in spike_in_counts], 
                       [x[0] for x in spike_in_counts], 
                       name = "Spike_in")

### Save and display the table
count_stats = pd.concat([raw_fastq_counts, cutadapt_fastq_counts, 
                         trimmed_fastq_counts, pass_counts, 
                         nonpass_counts, upass_counts, spike_in_counts], axis = 1)
count_stats['cutadapt%'] = round(count_stats.cutadapt/count_stats.Raw * 100, 1)
count_stats['Trimmed%'] = round(count_stats.Trimmed/count_stats.cutadapt * 100, 1)
count_stats['MAP%'] = round((count_stats.PASS + 
                             count_stats.nonPASS)/count_stats.Trimmed * 100, 1)
count_stats['PASS%'] = round(count_stats.PASS/(count_stats.PASS + 
                                               count_stats.nonPASS) * 100, 1)
count_stats['uPASS%'] = round(count_stats.uPASS/count_stats.PASS * 100, 1)
count_stats.index.name = 'Sample'
count_stats.to_csv(os.path.join(result_dir, 'ReadStats.csv'))

count_stats
# Out:
#                Raw   Clipped   Trimmed     PASS  nonPASS    uPASS  Ref  \
# Sample
# AS_C_M_1  20336015  20087819  19775958  7935940  2281311  4371141    0
# AS_E_M_1  19831252  19511876  19141593  8313583  2291747  4995405    0
# NT_C_M_1  17941284  17357593  17094958  5222647  2349419  2820067    0
# NT_E_M_1  18677381  17647960  17241928  6878130  2891651  4451328    0
# RC_C_M_1  15962498  15730852  15513212  4900692  2227557  2787946    0
# RC_E_M_1  23194272  22213241  21793451  9293822  3191140  5483451    0
#
#           Clipped%  Trimmed%  MAP%  PASS%  uPASS%
# Sample
# AS_C_M_1      98.8      98.4  51.7   77.7    55.1
# AS_E_M_1      98.4      98.1  55.4   78.4    60.1
# NT_C_M_1      96.7      98.5  44.3   69.0    54.0
# NT_E_M_1      94.5      97.7  56.7   70.4    64.7
# RC_C_M_1      98.5      98.6  45.9   68.8    56.9
# RC_E_M_1      95.8      98.1  57.3   74.4    59.0

# %% [markdown]
# ## T-stretch statistics

# %%
# summarize T-stretch length in different files
TS = count_5Ts(sam_dir=sam_dir)

# %%
# %%R -i result_dir,TS -w 1000 -h 800 -r 100
#
# require(dplyr)
# require(tidyr)
# require(magrittr)
# require(ggplot2)
#
# # convert to "long" format
# TS = gather(TS, sample_name, Count, -1)
# # re-format values
# TS$PASS_Type = toupper(sub("^.+\\.(.+)$", "\\1", TS$sample_name))
# TS$PASS_Type = sub("NO", "non", TS$PASS_Type)
# TS$Sample = sub("(^.+)\\.(.+)$", "\\1", TS$sample_name)
# # calculate percentage
# TS %<>% group_by(Sample) %>% mutate(Fraction = Count/sum(Count))
#
# # create the plot
# theme_set(theme_gray(base_size = 20))
# p = ggplot(TS, aes(x = T_Stretch_Length, y = Fraction, color = Sample)) +
#     geom_line(aes(linetype = PASS_Type), size = 1) +
#     scale_linetype_manual(values = c(3,1)) +
#     scale_x_continuous(limits = c(0, 25), breaks = 0:25) +
#     theme(legend.position=c(0.8, 0.5))  +
#     ggtitle("Distribution of 5' T-Stretch Length")
#
# # display in notebook
# print(p)
#
# # print to pdf
# pdf(file.path(result_dir, 'T_stretch_len_all.pdf'), 10, 8)
# print(p)
# dev.off()
# Out:
# png
#   2

# %% [markdown]
# ## Create UCSC genome browser tracks

# %%
samtools = '~/software/ucsc/samtools '
genomeCoverageBed = '~/software/ucsc/genomeCoverageBed '
genome_size = '~/projects/fud/ucsc/genomes/' + GENOME + '.chrom.sizes'
bedGraphToBigWig = '~/software/ucsc/bedGraphToBigWig '

# %%
# call the function to make UCSC genome browser tracks
make_url(project, EXPERIMENT, sam_dir, genome_size, genomeCoverageBed,
         bedGraphToBigWig)

# %%
# prepare for copying files
if not os.path.exists(os.path.join(sam_dir, PROJECT)):
    os.makedirs(os.path.join(sam_dir, PROJECT))
os.system('mkdir ' + os.path.join(sam_dir, PROJECT, EXPERIMENT))
os.system('mv ' + os.path.join(sam_dir, '*.bw ') +
          os.path.join(sam_dir, PROJECT, EXPERIMENT))
os.system('mv ' + os.path.join(sam_dir, 'bigwigCaller.txt ') +
          os.path.join(sam_dir, PROJECT, EXPERIMENT))
# Out:
# 0

# %%
# copy the bigwig and track definition files to the http-enabled intron server
cmd = 'scp -r ' + os.path.join(sam_dir, PROJECT) + \
      ' zhengdh@intron.njms.rutgers.edu:' + \
      '~/../www/zhengdh/bigwig/'
os.system(cmd)
cmd = 'rm -r ' + os.path.join(sam_dir, PROJECT)
os.system(cmd)

if SAVE_SPACE:
    cmd = 'rm -r ' + sam_dir
    os.system(cmd)

url = 'https://genome.ucsc.edu/cgi-bin/hgTracks?db=' + GENOME + \
      '&position=chr17%3A35092728-35095537&hgct_customText=' + \
      'http://intron.njms.rutgers.edu/zhengdh/bigwig/' + PROJECT + '/' + \
    EXPERIMENT + '/bigwigCaller.txt'
print('The following URL will be opened in a new tab automatically:\n')
print(url)
#msg = textwrap.fill(url, width=100)
#print(msg)
# wait for the server to be ready
sleep(5)
import webbrowser
_ = webbrowser.open(url)
# Out:
# The following URL will be opened in a new tab automatically:
#
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&position=chr17%3A35092728-35095537&hgct_customText=http://intron.njms.rutgers.edu/zhengdh/bigwig/stress/181210/bigwigCaller.txt

# %% [markdown]
# ## Download UCSC genome browser images for selected genes

# %%
import pandas as pd
input_dir = Path(result_dir)/"PM"
output_dir = input_dir/"UCSC_snapshot"
output_dir.mkdir(exist_ok=True, parents=True)
df = pd.read_csv(input_dir/"NT_normalized_deltaPM.csv")
print(df.shape)
df = df[df["NT_diff_1_norm_RED_n=10"].abs() >= 1].sort_values("gene_symbol")
print(df.shape)
df.columns
#df.head()
# Out:
# (1277, 22)
# (429, 22)
# Index(['gene_symbol', 'proximal_pA', 'distal_pA', 'UTR_length_proximal',
#        'UTR_length_distal', 'aUTR_length', 'NT_CP_CM_1_RED', 'NT_EP_EM_1_RED',
#        'NT_P_M_1_RED', 'NT_P_M_3_RED', 'NT_P_M_4_RED',
#        'NT_CP_CM_1_norm_RED_n=5', 'NT_EP_EM_1_norm_RED_n=5',
#        'NT_diff_1_norm_RED_n=5', 'NT_CP_CM_1_norm_RED_n=10',
#        'NT_EP_EM_1_norm_RED_n=10', 'NT_diff_1_norm_RED_n=10',
#        'NT_CP_CM_1_norm_RED_n=20', 'NT_EP_EM_1_norm_RED_n=20',
#        'NT_diff_1_norm_RED_n=20', 'description', 'url'],
#       dtype='object')

# %%
from urllib.request import urlopen, urlretrieve
for gene_symbol, url in zip(df.gene_symbol, df.url):
    print(gene_symbol)
    print(url)
    
    with urlopen(url) as conn:
        source = conn.read(100000)
        image_location = re.search('\/trash\/hgt\/hgt_genome(.*?)\.png',
                               str(source)).group()
        url_to_image = 'https://genome.ucsc.edu' + image_location
        UCSC_snapshot = output_dir/(gene_symbol+".png")
        urlretrieve(url_to_image, UCSC_snapshot)
# Out:
# 1700017B05Rik
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr9%3A57100705-57101585&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# 1810009A15Rik
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A8964326-8968021&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# 1810043G02Rik
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A77447235-77448499&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# 2210013O21Rik
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chrX%3A150175791-150175854&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# 2310022B05Rik
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A127158682-127162590&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# 2310057M21Rik
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr7%3A138485995-138486938&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# 2410004B18Rik
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr3%3A145606963-145608067&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# 2410015M20Rik
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr17%3A56746886-56747098&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# 3830406C13Rik
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr14%3A13133916-13136219&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# 9130011E15Rik
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A45891464-45893025&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# AU022252
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A118898517-118898913&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Abhd17c
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr7%3A91257689-91258405&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Abhd5
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr9%3A122288091-122291491&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Abracl
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A17730909-17731550&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Acox1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A116032817-116034360&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Actn1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr12%3A81268439-81268822&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Actr10
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr12%3A72062937-72063377&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Adsl
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A80799466-80799822&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Aff4
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A53234562-53234795&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Agpat5
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A18881927-18882094&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ak1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr2%3A32488785-32491173&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Amz2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A109297377-109300154&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Anapc16
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A59450315-59451683&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Anp32b
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A46485335-46485590&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Anxa4
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A86686438-86688022&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ap2a2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr7%3A148816872-148819577&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Aptx
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A40633161-40633617&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Arf6
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr12%3A70473669-70478065&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Arfrp1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr2%3A181092786-181094430&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Arl2bp
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A97196637-97198881&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Arl6ip5
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A97183269-97183397&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Arl8b
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A108773453-108773804&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Arpc3
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A122856139-122856191&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Arpc4
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A113338752-113339944&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Arpc5l
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr2%3A38870967-38871534&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Asap1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A63917577-63920945&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ascc2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A4582228-4586859&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Atad1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A32746924-32747443&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Atmin
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A119481044-119485444&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Atp5f1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr3%3A105745537-105745861&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Atxn10
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A85293417-85293713&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# B2m
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr2%3A121978546-121978651&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Bag5
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr12%3A112947534-112948222&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Bbip1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A54005482-54005577&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Bcas2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr3%3A102982474-102982842&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Bclaf1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A20058951-20063423&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Bex3
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chrX%3A132806438-132806517&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Bloc1s4
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A37138485-37139012&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Brcc3
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chrX%3A72692958-72703556&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Bri3bp
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A125932830-125943367&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Brix1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A10403846-10406634&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Bub3
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr7%3A138714326-138715770&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# C1galt1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A7820223-7827502&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cab39l
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr14%3A60165355-60168535&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Calml4
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr9%3A62723419-62723823&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Canx
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A50107724-50108712&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Capns1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr7%3A30971948-30972029&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ccdc174
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A91849462-91849958&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ccdc59
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A105284280-105285089&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ccdc86
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A11015529-11017330&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ccl2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A81850618-81851059&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ccny
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr18%3A9313605-9316724&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cct5
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A31520536-31520672&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cd2bp2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr7%3A134334716-134338011&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cd44
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr2%3A102651182-102651663&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cdc16
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A13781858-13781954&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cdc34
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A79150690-79151291&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cdc42
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A136875367-136876379&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cebpd
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr16%3A15887795-15890852&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cep57
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr9%3A13612039-13612827&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cfl2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr12%3A55960950-55962287&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cherp
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A74984302-74984626&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Chic2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A75402405-75402580&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Chmp3
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A71529463-71532270&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Chtop
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr3%3A90302512-90303985&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Clns1a
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr7%3A104867283-104867423&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cmtm4
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A106868816-106881964&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cnbp
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A87793030-87793214&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cnn2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A79458049-79458162&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Col16a1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A129776479-129776534&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Col1a1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A94812599-94814939&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Col5a1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr2%3A27893028-27893093&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cops4
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A100976778-100976834&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cox11
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A90505834-90506387&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cox14
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A99558446-99558578&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cox5b
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr1%3A36750086-36750671&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cox7a2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr9%3A79603146-79603238&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cpsf6
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A116785960-116786500&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cpsf7
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A10622103-10622264&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cript
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr17%3A87434408-87435396&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Csde1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr3%3A102861537-102862298&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Csnk1d
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A120822234-120825574&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ctsb
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr14%3A63761833-63762017&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ctsl
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr13%3A64465053-64465260&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cyb5b
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A109706315-109713055&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cyb5rl
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A106756894-106758943&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cyp51
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A4080651-4082607&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Dazap1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A79750384-79751407&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ddx19a
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A113498224-113499116&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ddx49
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A72816474-72817643&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ddx5
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A106641074-106643458&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ddx56
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A6158897-6159013&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Denr
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A124377347-124377684&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Derl2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A70819703-70824679&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Desi1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A81822215-81825166&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Dnlz
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr2%3A26202558-26206898&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Dusp11
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A85889643-85900130&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Dusp3
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A101831299-101835943&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Dusp7
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr9%3A106276367-106278614&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Dync1li2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A106940955-106943463&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Dynll2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A87792181-87795598&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Eef1g
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A9052528-9053096&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ehd1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A6298302-6300686&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Eif1ad
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A5369618-5372134&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Eif4a1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A69480256-69480984&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Eif4ebp2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A60889597-60896169&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Eif4g2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr7%3A118213642-118216049&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Eif5
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr12%3A112782297-112785633&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Emc3
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A113464419-113466258&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Eny2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A44267298-44267450&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Epb41l3
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr17%3A69638428-69639624&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ercc8
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr13%3A108984465-108985409&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Errfi1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A150242293-150243230&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Exosc4
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A76159732-76161560&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Exosc9
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr3%3A36464527-36464687&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Faf2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr13%3A54762900-54763109&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Fam104a
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A113521840-113525016&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Fam133b
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A3569598-3570446&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Fam136a
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A86318366-86320613&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Fam178a
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A45057128-45058655&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Fam32a
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A74746715-74747538&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Fbxo5
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A4547332-4547397&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Fcgrt
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr7%3A52348338-52348466&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Fech
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr18%3A64615837-64617281&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Fkbp1a
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr2%3A151386131-151387858&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Fosl2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A32454072-32462132&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Fxn
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A24336193-24336408&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# G3bp1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A55313286-55314746&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Gatad1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A3639389-3641925&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Gfer
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr17%3A24829632-24831647&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Glg1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A113675519-113682296&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Glud1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr14%3A35157112-35158415&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Gmcl1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A86641520-86642496&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Gng12
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A66966260-66972965&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Golt1b
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A142349792-142353239&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Gorasp2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr2%3A70529344-70529928&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Gpi1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr7%3A34987135-34987192&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Grk2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A4285484-4287557&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Gsto1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A47938873-47939410&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Gtf2h5
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr17%3A6084691-6085255&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Gtf3c2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A31457776-31460188&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Gtf3c6
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A39966595-39970247&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Haus2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr2%3A120443786-120448462&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Hdac3
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr18%3A38096587-38096770&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Higd1a
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr9%3A121757195-121759132&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Hnrnpa0
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr13%3A58226724-58228792&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Hnrnpc
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr14%3A52693953-52694649&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Hnrnpk
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr13%3A58492447-58492651&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Hnrnpul1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr7%3A26506028-26506660&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Hsf1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A76331326-76331429&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Hspa9
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr18%3A35096960-35097404&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Hypk
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr2%3A121283984-121284231&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ier3ip1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr18%3A77178941-77180817&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Il6st
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr13%3A113295798-113300805&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ilkap
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr1%3A93269462-93273391&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Incenp
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A9946806-9946922&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ipo5
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr14%3A121345813-121346909&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ipo9
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr1%3A137277813-137282132&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Isca1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr13%3A59856127-59858736&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Isy1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A87768274-87768953&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Itm2b
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr14%3A73761977-73762946&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Jun
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A94716240-94716440&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Kcmf1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A72790396-72793208&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Kctd20
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr17%3A29104064-29107304&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Kctd5
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr17%3A24184248-24186055&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Kdelr2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A144181768-144183348&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Kras
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A145163837-145169385&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Lamp1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A13175188-13175755&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Lemd2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr17%3A27326466-27326787&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Letmd1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A100308070-100310102&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Lgals1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A78760488-78761032&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Lias
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A65800097-65800522&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Lin37
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr7%3A31340445-31340524&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Loxl1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr9%3A58135102-58136845&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Lrrc28
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr7%3A74657565-74660494&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Lsm14a
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr7%3A35129655-35129755&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Lyrm9
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A78652730-78652913&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Mak16
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A32269872-32270137&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Map1lc3b
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A124120409-124122458&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Map2k4
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A65501014-65504373&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Map4k4
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr1%3A40081137-40083821&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Mapk1ip1l
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr14%3A47942710-47942935&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# March5
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A37296153-37296786&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Mbnl1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr3%3A60433118-60433853&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Mcts1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chrX%3A35966552-35966748&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Meaf6
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A124787043-124787403&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Med11
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A70266949-70267318&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Med21
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A146598937-146599185&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Med23
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A24632964-24633356&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Med7
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A46254993-46255125&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Med9
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A59774083-59776247&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Minpp1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A32589696-32589892&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Mlec
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A115596013-115597572&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Mmd
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A90139035-90140170&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Mrpl17
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr7%3A112957649-112958385&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Mrpl19
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A81908717-81912358&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Mrpl36
# ...
# Stk11
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A79593110-79593526&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Suds3
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A117541313-117542824&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Supv3l1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A61892068-61892147&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Surf4
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr2%3A26775168-26776740&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Syf2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A134492890-134493642&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Szrd1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A140667779-140672386&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tax1bp1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A52716334-52716917&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tceal8
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chrX%3A132704503-132704984&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tcerg1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr18%3A42735181-42735284&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tcp1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr17%3A13117172-13118180&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tesk1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A43460500-43461080&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tex261
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A83717940-83721683&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tfdp1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A13378322-13378482&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Thap7
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr16%3A17527992-17528240&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Timm10b
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr7%3A112789618-112790603&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Timm13
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A80362290-80362779&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Timm22
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A76227786-76228169&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tm9sf4
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr2%3A153033785-153037005&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tmem167
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr13%3A90244194-90244641&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tmem183a
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr1%3A136241962-136244811&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tmem248
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A130716241-130720632&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tmem261
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A74923196-74923453&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tmem33
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A67677142-67684550&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tmem39a
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr16%3A38591378-38591537&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tmpo
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A90609545-90612632&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tomm20
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A129452830-129459781&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tomm22
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A79502845-79503444&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tomm40l
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr1%3A173149179-173149434&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tpm1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr9%3A66870056-66871433&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tsn
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr1%3A120194187-120197827&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ttll12
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A83405987-83406330&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tubb5
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr17%3A35970431-35972192&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tusc2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr9%3A107466840-107468975&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Txlna
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A129302300-129306412&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Txn2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A77745397-77745721&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Uap1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr1%3A172072115-172072191&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ube2b
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A51799700-51799949&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ube2c
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr2%3A164598349-164598406&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ube2d2a
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr18%3A35965726-35967178&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ube2d3
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr3%3A135127917-135129302&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ube2f
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr1%3A93182295-93182551&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ube2j1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A33135835-33140503&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ube2v2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr16%3A15552430-15556878&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ubp1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr9%3A113886020-113886416&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Uck2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr1%3A169151438-169157813&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Uqcc3
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A8954481-8954848&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Uqcr10
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A4601720-4602065&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Uqcrfs1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr13%3A30632284-30632435&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Usp4
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr9%3A108294458-108294985&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Usp47
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr7%3A119253547-119255348&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Utp11
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A124355984-124356080&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Vapb
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr2%3A173603312-173605361&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Vps29
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A122812860-122813440&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Wdr18
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A79429656-79432769&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Wdr48
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr9%3A119834330-119836161&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Wdr82
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr9%3A106091396-106094116&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Wwp2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A110080421-110083185&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Xpo1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A23195833-23197405&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Yeats4
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A116652160-116652311&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Yrdc
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A124532228-124532565&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ywhaq
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr12%3A21395804-21396328&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Zbtb8os
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A129024247-129024352&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Zcchc17
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A129993044-129993456&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Zeb1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr18%3A5774632-5775735&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Zfp384
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A124987538-124987998&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Zfp593
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A133798550-133801237&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Zfp706
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A36927947-36931196&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Zranb2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr3%3A157209180-157212012&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI

# %%
import pandas as pd
input_dir = Path(result_dir)/"PM"
output_dir = input_dir/"AS_UCSC_snapshot"
output_dir.mkdir(exist_ok=True, parents=True)
df = pd.read_csv(input_dir/"AS_normalized_deltaPM.csv")
print(df.shape)
df = df[(df["AS_diff_1_norm_RED_n=10"].abs() >= 1) & (df['aUTR_length'] >= 1000)].sort_values("gene_symbol")
print(df.shape)
df.columns
#df.head()
# Out:
# (1560, 35)
# (93, 35)
# Index(['gene_symbol', 'proximal_pA', 'distal_pA', 'ER', 'Golgi', 'Membrane',
#        'Nucleus', 'Cytoplasm', 'Mitochondria', 'Lysosome', 'Peroxisome',
#        'Cytoskeleton', 'Secreted', 'Secreted_likely', 'Secreted_highlylikely',
#        'Secreted_weaklylikely', 'UTR_length_proximal', 'UTR_length_distal',
#        'aUTR_length', 'AS_CP_CM_1_RED', 'AS_EP_EM_1_RED', 'AS_P_M_1_RED',
#        'AS_P_M_3_RED', 'AS_P_M_4_RED', 'AS_CP_CM_1_norm_RED_n=5',
#        'AS_EP_EM_1_norm_RED_n=5', 'AS_diff_1_norm_RED_n=5',
#        'AS_CP_CM_1_norm_RED_n=10', 'AS_EP_EM_1_norm_RED_n=10',
#        'AS_diff_1_norm_RED_n=10', 'AS_CP_CM_1_norm_RED_n=20',
#        'AS_EP_EM_1_norm_RED_n=20', 'AS_diff_1_norm_RED_n=20', 'description',
#        'url'],
#       dtype='object')

# %%
from urllib.request import urlopen, urlretrieve
for gene_symbol, url in zip(df.gene_symbol, df.url):
    print(gene_symbol)
    print(url)
    
    with urlopen(url) as conn:
        source = conn.read(100000)
        image_location = re.search('\/trash\/hgt\/hgt_genome(.*?)\.png',
                               str(source)).group()
        url_to_image = 'https://genome.ucsc.edu' + image_location
        UCSC_snapshot = output_dir/(gene_symbol+".png")
        urlretrieve(url_to_image, UCSC_snapshot)
# Out:
# 1810013L24Rik
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr16%3A8856043-8859043&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Abhd5
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr9%3A122288091-122291491&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Adamtsl5
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A79801992-79804247&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Amz2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A109297377-109300154&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ankrd40
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A94200276-94204112&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Arf6
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr12%3A70473669-70478065&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Asap1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A63917577-63920945&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Azin1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A38417133-38420356&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Bag1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A40881761-40884016&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Bri3bp
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A125932830-125943367&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Btbd1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr7%3A88936239-88939126&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cacul1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A60601868-60605573&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cbx5
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A103018017-103033857&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ccng1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A40560954-40565362&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cd164
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A41247854-41251845&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cd2bp2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr7%3A134334716-134338011&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cdkn2aipnl
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A51789247-51791360&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Cmtm4
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A106868816-106881964&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Csnk1d
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A120822234-120825574&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Dab2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A6389051-6391259&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Dcaf7
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A105914340-105922733&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Dctn4
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr18%3A60716148-60719168&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ddx21
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A62042072-62045792&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ddx5
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A106641074-106643458&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Derl2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A70819703-70824679&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Eif1ad
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A5369618-5372134&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Eif4ebp2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A60889597-60896169&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Elk3
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A92709205-92713028&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Eps15
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A109057321-109061233&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ergic1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr17%3A26791506-26794666&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Fam136a
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A86318366-86320613&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Fitm2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr2%3A163290902-163295759&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Foxp1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A98873388-98881221&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Fundc2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chrX%3A72638881-72643705&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Galnt10
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A57598843-57601719&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Gfer
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr17%3A24829632-24831647&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Gnb1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A154931422-154934029&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Gng12
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A66966260-66972965&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Golt1b
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A142349792-142353239&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Grk2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A4285484-4287557&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Hdgfrp3
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr7%3A89024055-89032390&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Hif1an
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A44645744-44652436&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Kctd20
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr17%3A29104064-29107304&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Letmd1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A100308070-100310102&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Lgals8
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr13%3A12530994-12533755&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Luc7l
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr17%3A26417145-26424217&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Mapkapk2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr1%3A132949621-132952260&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Mtch2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr2%3A90704923-90707423&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Mtdh
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A34069902-34074418&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Mtpn
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A35457576-35463536&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Mtss1l
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A113263105-113266029&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Nfkb2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A46384836-46391539&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Nktr
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr9%3A121662291-121667183&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Opa1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr16%3A29650610-29656026&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Oxct1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A4103482-4105961&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Pcbp2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A102328787-102331067&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Phf20l1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A66474777-66477253&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Pmepa1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr2%3A173048789-173053501&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ptbp3
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A59483091-59489727&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Pttg1ip
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr10%3A77059283-77062207&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Pum3
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A27462522-27465218&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Rbms1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr2%3A60587244-60591272&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Rdh10
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr1%3A16122038-16124406&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Rfk
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A17473598-17476583&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Rnf121
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr7%3A109167150-109169183&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Rock2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr12%3A16991838-16994063&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Rpl22
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A151705789-151708972&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Rrp1b
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr17%3A32196416-32200940&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Rwdd4a
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A48635345-48639122&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Sap30bp
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A115824926-115829070&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Sav1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr12%3A71065490-71067538&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Sdc2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr15%3A32961308-32965541&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Sh3pxd2a
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr19%3A47332130-47342273&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Slain2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A73366550-73371239&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Slc30a1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr1%3A193732440-193738608&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Slc35f6
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A30960455-30962582&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Smim7
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr8%3A75089310-75091357&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Sppl3
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A115547196-115549332&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Srr
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A74719606-74722367&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ssr1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr13%3A38069416-38072015&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ssr3
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr3%3A65182534-65186741&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Szrd1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A140667779-140672386&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tex261
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr6%3A83717940-83721683&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tmem183a
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr1%3A136241962-136244811&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tmem30a
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr9%3A79615823-79619531&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tnfaip1
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr11%3A78335440-78339312&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tpx2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr2%3A152719103-152721712&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Tsn
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr1%3A120194187-120197827&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Ube2v2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr16%3A15552430-15556878&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Vps33a
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr5%3A123978290-123981577&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Zdhhc18
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr4%3A133160371-133163754&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Zmat3
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr3%3A32231006-32241863&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
# Zranb2
# https://genome.ucsc.edu/cgi-bin/hgTracks?db=mm9&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr3%3A157209180-157212012&hgsid=703198623_15Ka4gFZgGap6XtCm0vnqEZaW8iI
